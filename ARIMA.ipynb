# %% [markdown]
# # ARIMA

# %% [markdown]
# #### STATIONARY SERIES
#
# ####    1. Mean is constant
# ####    2. Standard Deviation is constant
# ####    3. No seasonality

# %% [markdown]
# ![5K7we.jpg](attachment:5K7we.jpg)

# %% [markdown]
# # Autocorrelation

# %% [markdown]
# ![1_vyx2eD_OrwtO6i7qtpIBug.png](attachment:1_vyx2eD_OrwtO6i7qtpIBug.png)

# %% [markdown]
# # Partial Autocorrelation

# %% [markdown]
# ![pacf.png](attachment:pacf.png)

# %% [markdown]
# # AR Model

# %% [markdown]
# ![ar.png](attachment:ar.png)

# %% [markdown]
# # MA Model

# %% [markdown]
# ![acf.png](attachment:acf.png)

# %% [markdown]
# # ARMA Model

# %% [markdown]
# ![arma.png](attachment:arma.png)

# %% [markdown]
# # ARIMA Model

# %% [markdown]
# ![arima.png](attachment:arima.png)

# %% [markdown]
# ![flowchart.webp](attachment:flowchart.webp)

# %% [markdown]
# # Pros and Cons

# %% [markdown]
# #### Pros :
#
# ####       1. Better understand the time series patterns
# ####       2. Forecasting based on ARIMA with small data works best.
# ####       3. Captures uncertainty in the data.
#
# #### Cons :
#
# ####        1. Sometimes non-linear associationns deteriorate the algorithm
# ####        2. Too much data requires too many computations.
